# %%
# import torch
import config
from model import Lightning_YOLO
from pytorch_lightning import Trainer, LightningDataModule
# Out:
# d:\Anaconda\envs\theschoolofai\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
import pytorch_lightning.utilities.model_summary

# %%
model = Lightning_YOLO(num_classes=config.NUM_CLASSES)

# %%
from pytorch_lightning.utilities import model_summary
# print(dir(model_summary))
summary = model_summary.ModelSummary(model)
print(summary)
# Out:
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | layers  | ModuleList | 61.6 M
# 1 | loss_fn | YoloLoss   | 0
# ---------------------------------------
# 61.6 M    Trainable params
# 0         Non-trainable params
# 61.6 M    Total params
# 246.506   Total estimated model params size (MB)

# %%
from utils import get_loaders
train_loader, test_loader, train_eval_loader = get_loaders(
    train_csv_path=config.DATASET + "/train.csv", test_csv_path=config.DATASET + "/test.csv"
)

# %%
class PascalDataModule(LightningDataModule):
    def __init__(self, data_dir: str = "./"):
        super().__init__()
        # self.data_dir = data_dir
        # self.transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

    def prepare_data(self):
        pass
        # download
        # CIFAR10(self.data_dir, train=True, download=True)
        # CIFAR10(self.data_dir, train=False, download=True)

    def setup(self, stage: str):
        pass
        # Assign train/val datasets for use in dataloaders
        # if stage == "fit":
        #     cifar_full = CIFAR10(self.data_dir, train=True, transform=self.transform)
        #     self.cifar_train, self.cifar_val = random_split(cifar_full, [55000, 5000])

        # # Assign test dataset for use in dataloader(s)
        # if stage == "test":
        #     self.cifar_test = CIFAR10(self.data_dir, train=False, transform=self.transform)

        # if stage == "predict":
        #     self.cifar_predict = CIFAR10(self.data_dir, train=False, transform=self.transform)

    def train_dataloader(self):
        return train_loader

    def val_dataloader(self):
        return train_eval_loader

    def test_dataloader(self):
        return test_loader

    def predict_dataloader(self):
        return test_loader

# %%
len(train_loader)
# Out:
# 518

# %%
dm = PascalDataModule()

# %%
# initialize the trainer
trainer = Trainer(
    max_epochs = 20,
    precision="16-mixed"
)
trainer.fit(model,datamodule=dm)
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# d:\Anaconda\envs\theschoolofai\lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:67: UserWarning: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#   warning_cache.warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | layers  | ModuleList | 61.6 M
# 1 | loss_fn | YoloLoss   | 0
# ---------------------------------------
# 61.6 M    Trainable params
# 0         Non-trainable params
# 61.6 M    Total params
# 246.506   Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:32<00:00, 16.15s/it]{'val loss': 47.080963134765625, 'Obj val accuracy': '100.000000%', 'No obj val accuracy is': '0.000000%', 'Class val accuracy is': '3.655914%'}
# Epoch 0:   0%|          | 1/518 [00:52<7:28:12, 52.02s/it, v_num=9]
# d:\Anaconda\envs\theschoolofai\lib\site-packages\torch\optim\lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 0: 100%|██████████| 518/518 [06:12<00:00,  1.39it/s, v_num=9]{'val loss': 15.077645301818848, 'Obj val accuracy': '31.292517%', 'No obj val accuracy is': '39.881065%', 'Class val accuracy is': '25.170067%'}
# Epoch 0: 100%|██████████| 518/518 [08:10<00:00,  1.06it/s, v_num=9]{'train loss': 13.70479965209961, 'Obj train accuracy': '38.636364%', 'No obj train accuracy is': '42.792816%', 'Class train accuracy is': '40.151516%'}
# Epoch 1: 100%|██████████| 518/518 [05:08<00:00,  1.68it/s, v_num=9]{'val loss': 13.181303024291992, 'Obj val accuracy': '28.472221%', 'No obj val accuracy is': '96.060127%', 'Class val accuracy is': '32.638889%'}
# Epoch 1: 100%|██████████| 518/518 [07:19<00:00,  1.18it/s, v_num=9]{'train loss': 10.812796592712402, 'Obj train accuracy': '25.185186%', 'No obj train accuracy is': '97.414413%', 'Class train accuracy is': '34.814816%'}
# Epoch 2: 100%|██████████| 518/518 [05:06<00:00,  1.69it/s, v_num=9]{'val loss': 12.735126495361328, 'Obj val accuracy': '30.994152%', 'No obj val accuracy is': '95.582764%', 'Class val accuracy is': '43.859650%'}
# Epoch 2: 100%|██████████| 518/518 [07:06<00:00,  1.21it/s, v_num=9]{'train loss': 10.708419799804688, 'Obj train accuracy': '27.868853%', 'No obj train accuracy is': '97.538116%', 'Class train accuracy is': '31.693989%'}
# Epoch 3: 100%|██████████| 518/518 [04:09<00:00,  2.08it/s, v_num=9]{'val loss': 11.881553649902344, 'Obj val accuracy': '36.734695%', 'No obj val accuracy is': '96.530518%', 'Class val accuracy is': '40.136055%'}
# Epoch 3: 100%|██████████| 518/518 [06:07<00:00,  1.41it/s, v_num=9]{'train loss': 10.409162521362305, 'Obj train accuracy': '48.148148%', 'No obj train accuracy is': '97.218300%', 'Class train accuracy is': '39.259258%'}
# Epoch 4: 100%|██████████| 518/518 [05:10<00:00,  1.67it/s, v_num=9]{'val loss': 12.458229064941406, 'Obj val accuracy': '42.222221%', 'No obj val accuracy is': '97.185532%', 'Class val accuracy is': '34.074074%'}
# Epoch 4: 100%|██████████| 518/518 [07:07<00:00,  1.21it/s, v_num=9]{'train loss': 8.873164176940918, 'Obj train accuracy': '45.833336%', 'No obj train accuracy is': '96.457092%', 'Class train accuracy is': '59.027779%'}
# Epoch 5: 100%|██████████| 518/518 [05:08<00:00,  1.68it/s, v_num=9]{'val loss': 9.780906677246094, 'Obj val accuracy': '62.345676%', 'No obj val accuracy is': '96.094925%', 'Class val accuracy is': '50.000000%'}
# Epoch 5: 100%|██████████| 518/518 [07:07<00:00,  1.21it/s, v_num=9]{'train loss': 8.855453491210938, 'Obj train accuracy': '71.717171%', 'No obj train accuracy is': '97.089905%', 'Class train accuracy is': '41.414143%'}
# Epoch 6: 100%|██████████| 518/518 [05:10<00:00,  1.67it/s, v_num=9]{'val loss': 13.594552040100098, 'Obj val accuracy': '42.857143%', 'No obj val accuracy is': '97.227844%', 'Class val accuracy is': '45.714287%'}
# Epoch 6: 100%|██████████| 518/518 [07:10<00:00,  1.20it/s, v_num=9]{'train loss': 7.1937360763549805, 'Obj train accuracy': '55.072464%', 'No obj train accuracy is': '97.312561%', 'Class train accuracy is': '52.173912%'}
# Epoch 7: 100%|██████████| 518/518 [05:09<00:00,  1.67it/s, v_num=9]{'val loss': 9.924062728881836, 'Obj val accuracy': '58.757061%', 'No obj val accuracy is': '96.092682%', 'Class val accuracy is': '60.451977%'}
# Epoch 7: 100%|██████████| 518/518 [07:10<00:00,  1.20it/s, v_num=9]{'train loss': 7.094023704528809, 'Obj train accuracy': '62.222225%', 'No obj train accuracy is': '97.341026%', 'Class train accuracy is': '58.888889%'}
# Epoch 8: 100%|██████████| 518/518 [05:11<00:00,  1.66it/s, v_num=9]{'val loss': 6.69514274597168, 'Obj val accuracy': '68.571434%', 'No obj val accuracy is': '97.644699%', 'Class val accuracy is': '63.809525%'}
# Epoch 8: 100%|██████████| 518/518 [07:09<00:00,  1.21it/s, v_num=9]{'train loss': 6.912813663482666, 'Obj train accuracy': '59.259258%', 'No obj train accuracy is': '97.792351%', 'Class train accuracy is': '57.037037%'}
# Epoch 9: 100%|██████████| 518/518 [05:11<00:00,  1.66it/s, v_num=9]{'val loss': 8.13341236114502, 'Obj val accuracy': '60.683762%', 'No obj val accuracy is': '98.044319%', 'Class val accuracy is': '50.427353%'}
# Epoch 9: 100%|██████████| 518/518 [07:08<00:00,  1.21it/s, v_num=9]{'train loss': 9.525468826293945, 'Obj train accuracy': '52.450977%', 'No obj train accuracy is': '97.510681%', 'Class train accuracy is': '57.352943%'}
# Epoch 10: 100%|██████████| 518/518 [05:11<00:00,  1.66it/s, v_num=9]{'val loss': 10.172321319580078, 'Obj val accuracy': '57.037037%', 'No obj val accuracy is': '98.371460%', 'Class val accuracy is': '51.851852%'}
# Epoch 10: 100%|██████████| 518/518 [07:08<00:00,  1.21it/s, v_num=9]{'train loss': 7.215067386627197, 'Obj train accuracy': '68.217056%', 'No obj train accuracy is': '97.522942%', 'Class train accuracy is': '50.387596%'}
# Epoch 11: 100%|██████████| 518/518 [05:12<00:00,  1.66it/s, v_num=9]{'val loss': 8.023052215576172, 'Obj val accuracy': '55.555557%', 'No obj val accuracy is': '98.084557%', 'Class val accuracy is': '58.518517%'}
# Epoch 11: 100%|██████████| 518/518 [07:09<00:00,  1.21it/s, v_num=9]{'train loss': 6.710195064544678, 'Obj train accuracy': '59.349590%', 'No obj train accuracy is': '97.642426%', 'Class train accuracy is': '66.666672%'}
# Epoch 12: 100%|██████████| 518/518 [05:13<00:00,  1.65it/s, v_num=9]{'val loss': 7.477604389190674, 'Obj val accuracy': '68.243240%', 'No obj val accuracy is': '97.381142%', 'Class val accuracy is': '72.972969%'}
# Epoch 12: 100%|██████████| 518/518 [07:09<00:00,  1.20it/s, v_num=9]{'train loss': 6.224013328552246, 'Obj train accuracy': '79.797974%', 'No obj train accuracy is': '97.531982%', 'Class train accuracy is': '66.666672%'}
# Epoch 13: 100%|██████████| 518/518 [05:12<00:00,  1.66it/s, v_num=9]{'val loss': 7.95557975769043, 'Obj val accuracy': '59.854012%', 'No obj val accuracy is': '98.269562%', 'Class val accuracy is': '63.503647%'}
# Epoch 13: 100%|██████████| 518/518 [07:09<00:00,  1.21it/s, v_num=9]{'train loss': 8.296770095825195, 'Obj train accuracy': '62.424244%', 'No obj train accuracy is': '97.703659%', 'Class train accuracy is': '58.181816%'}
# Epoch 14: 100%|██████████| 518/518 [05:12<00:00,  1.66it/s, v_num=9]{'val loss': 4.530454158782959, 'Obj val accuracy': '72.649574%', 'No obj val accuracy is': '97.899834%', 'Class val accuracy is': '82.905983%'}
# Epoch 14: 100%|██████████| 518/518 [07:09<00:00,  1.21it/s, v_num=9]{'train loss': 6.231652736663818, 'Obj train accuracy': '70.833328%', 'No obj train accuracy is': '97.512833%', 'Class train accuracy is': '65.972221%'}
# Epoch 15: 100%|██████████| 518/518 [05:12<00:00,  1.66it/s, v_num=9]{'val loss': 7.107839107513428, 'Obj val accuracy': '55.833332%', 'No obj val accuracy is': '98.200920%', 'Class val accuracy is': '72.500000%'}
# Epoch 15: 100%|██████████| 518/518 [07:11<00:00,  1.20it/s, v_num=9]{'train loss': 6.5511088371276855, 'Obj train accuracy': '75.000000%', 'No obj train accuracy is': '97.674347%', 'Class train accuracy is': '62.037041%'}
# Epoch 16: 100%|██████████| 518/518 [05:10<00:00,  1.67it/s, v_num=9]{'val loss': 4.505236625671387, 'Obj val accuracy': '71.428574%', 'No obj val accuracy is': '98.033920%', 'Class val accuracy is': '87.074829%'}
# Epoch 16: 100%|██████████| 518/518 [07:07<00:00,  1.21it/s, v_num=9]{'train loss': 5.137434482574463, 'Obj train accuracy': '68.750000%', 'No obj train accuracy is': '97.561554%', 'Class train accuracy is': '79.861107%'}
# Epoch 17: 100%|██████████| 518/518 [05:07<00:00,  1.68it/s, v_num=9]{'val loss': 6.430824279785156, 'Obj val accuracy': '68.840584%', 'No obj val accuracy is': '97.947754%', 'Class val accuracy is': '77.536232%'}
# Epoch 17: 100%|██████████| 518/518 [07:03<00:00,  1.22it/s, v_num=9]{'train loss': 4.757088661193848, 'Obj train accuracy': '72.222221%', 'No obj train accuracy is': '97.665878%', 'Class train accuracy is': '77.777779%'}
# Epoch 18: 100%|██████████| 518/518 [05:09<00:00,  1.68it/s, v_num=9]{'val loss': 5.3058881759643555, 'Obj val accuracy': '66.666672%', 'No obj val accuracy is': '98.162590%', 'Class val accuracy is': '78.472221%'}
# Epoch 18: 100%|██████████| 518/518 [07:05<00:00,  1.22it/s, v_num=9]{'train loss': 4.725634574890137, 'Obj train accuracy': '77.519379%', 'No obj train accuracy is': '97.882118%', 'Class train accuracy is': '79.844963%'}
# Epoch 19: 100%|██████████| 518/518 [05:05<00:00,  1.69it/s, v_num=9]{'val loss': 6.3193817138671875, 'Obj val accuracy': '72.514618%', 'No obj val accuracy is': '97.672195%', 'Class val accuracy is': '82.456139%'}
# Epoch 19: 100%|██████████| 518/518 [07:03<00:00,  1.22it/s, v_num=9]{'train loss': 5.584275245666504, 'Obj train accuracy': '67.796616%', 'No obj train accuracy is': '97.652657%', 'Class train accuracy is': '76.271187%'}
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|██████████| 518/518 [07:09<00:00,  1.21it/s, v_num=9]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import  mean_average_precision,  get_evaluation_bboxes

# %%
pred_boxes, true_boxes = get_evaluation_bboxes(
    test_loader,
    model,
    iou_threshold=config.NMS_IOU_THRESH,
    anchors=config.ANCHORS,
    threshold=config.CONF_THRESHOLD,
)
# Out:
# 100%|██████████| 155/155 [1:33:55<00:00, 36.36s/it]

# %%
mapval = mean_average_precision(
    pred_boxes,
    true_boxes,
    iou_threshold=config.MAP_IOU_THRESH,
    box_format="midpoint",
    num_classes=config.NUM_CLASSES,
)
print(f"MAP: {mapval.item()}")
# Out:
# MAP: 0.42522239685058594

# %%
trainer.save_checkpoint("lightingYoloV2.ckpt")
